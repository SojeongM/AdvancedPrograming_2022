# %%
import random

#random.random() -> 0.0에서 1.0사이의 실수 중에서 난수값 리턴
print(random.random()) 
# ex) 0.2664520652284096

#random.uniform(a, b) -> 괄호 안 두 수 사이의 실수 중에서 난수값을 리턴
print(random.uniform(10, 30)) 
# ex) 28.038707445386397

#random.randint(a, b) -> 괄호 안 두 수 사이의 정수 중에서 난수값을 리턴
print(random.randint(100,200))
# ex) 106

#random.choice(sample) 함수 -> sample에서 무작위로 하나를 선택하여 리턴
data = [1, 2, 3, 4, 5, 6, 7]
print(random.choice(data))
# ex) 5

#random.sample(sample, n) -> 입력으로 받은 sample 에서 정한 개수만큼  무작위로 뽑아 리턴함
data = [1, 2, 3, 4, 'apple', 'banna']
print(random.sample(data, 3))
# ex) ['apple', 2, 3]
print(random.sample(data, 3))
# ex) ['apple', 3, 'banna']
print(random.sample(data, 5))
# ex) [2, 3, 1, 'apple', 4]
# Out:
# 0.64829390603245
# 14.071492121828989
# 185
# 1
# [1, 'apple', 4]
# [1, 2, 'apple']
# [2, 4, 'banna', 'apple', 1]

# %% [markdown]
# # 실습1. 난수 히스토그램 그리기 (Python Random module)

# %%
# import packages
import matplotlib.pyplot as plt
from tqdm import tqdm # optional
import random

# %%
# 100번 수행
num_iterations = 100
random_integers = []

## write answer
##
##
##
##
##
##
##
for i in range(num_iterations):
  random_integers.append(random.randrange(1,100))


fig = plt.figure()
plt.hist(random_integers)
plt.title(f"Check Uniform Distribution of {num_iterations} iterations")
plt.xlabel("Numbers")
plt.ylabel("N of each number")
plt.xlim([0, 99])
plt.show()

# %% [markdown]
# # 실습 2. Linear Congruential Generator(LCG) 구현
#
# Linear Congruential Generator(LCG) 구현
#
# X_(n+1) = (aX_n+C) mod m
#
# LCG는 다음과 같은 인자들로 유일하게 결정됨
#   - 0 < m, 0 < a < m, 0 <= c < m, 0<=초기값 < m
#
# 최대 주기 m을 가지기 위한 필요충분조건
#
#   - c와 m이 서로소, a-1이 m의 모든 소인수로 나뉨
#   - m이 4의 배수면 a-1도 4의 배수

# %%
def lcg(seed, loop, m=2**32, a=214013, c=2531011):
    for i in range(loop):
        seed = (a*seed + c) % m
        yield seed

# %%
# 100번 수행
num_iterations = 1000
random_generator = lcg(seed=13, loop=num_iterations, m=2**32)
random_integers = []


for i in random_generator:
  random_integers.append(i)

## write answer
##
##
##
##
##
##
##


fig = plt.figure()
plt.hist(random_integers)
plt.title(f"Check Uniform Distribution of {num_iterations} iterations")
plt.xlabel("Numbers")
plt.ylabel("N of each number")
plt.xlim([0, 2**32])
plt.show()

# %% [markdown]
# # 난수들 중 Uniform Distribution 확인

# %%
# LCG 256
from collections import defaultdict

for num_iterations in [1000,10000,100000]:
    random_generator = lcg(seed=13, loop=num_iterations, m=2**32)
    random_integers = []
    sum=0
    for j in random_generator:
        random_integers.append(j)
        sum=sum+j
    for _ in range(num_iterations):
        ## write answer
        ##
        ##
        ##
        ##
        sum=sum+j
        ##
        ##
        pass
    ev=sum/num_iterations
    print(ev)
    error = None
    print(f"LCG 시행횟수 {num_iterations}에서의 uniform distribution 오차 : {error}")
# Out:
# 2470052669.228
# LCG 시행횟수 1000에서의 uniform distribution 오차 : None
# 5353914316.4408
# LCG 시행횟수 10000에서의 uniform distribution 오차 : None
# 3983230124.57648
# LCG 시행횟수 100000에서의 uniform distribution 오차 : None

# %%
# 메르센 트위스터 0-99
from collections import defaultdict

for num_iterations in [1000,10000,100000]:
    
    for _ in range(num_iterations):
       
        pass

    
    error = None
    print(f"메르센 트위스터 시행횟수 {num_iterations}에서의 uniform distribution 오차 : {error}")

# %% [markdown]
# # 실습 3. 주사위 합이 8인 경우

# %%
# !pip install termcolor
from termcolor import colored
# !pip install colorama
from colorama import init, Fore, Back, Style
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (0.4.5)

# %%
def roll_dice():
    line=[]
    x= random.randint(1,6)
    y= random.randint(1,6)
    return x, y
    pass

# %%
dice_tries = []
print(dice_tries)
num_iterations = 100
hits = 0
for _ in range(num_iterations):
    dice_tries.append(roll_dice())
   
    pass
print("="*100)

print(colored("* 두 주사위의 합이 8인 경우에는 cyan 색의 음영이 들어가 있음 *", 'red'))
for i in range(num_iterations):
  
  if((i+1)%5==0):
    
    if dice_tries[i][0]+dice_tries[i][1]==8:
      hits=hits+1
      print(Back.CYAN+ Fore.YELLOW + "try ", i, ":",dice_tries[i][0], dice_tries[i][1], end=' ' + Style.RESET_ALL)
      print()
    else:
      print("try ", i, ":",dice_tries[i][0], dice_tries[i][1])
  else:
    if dice_tries[i][0]+dice_tries[i][1]==8:
      hits=hits+1
    
      print(Back.CYAN+ Fore.YELLOW + "try ", i, ":",dice_tries[i][0], dice_tries[i][1], end=' ' + Style.RESET_ALL)
      print(end=' ')
    else:
      print("try ", i, ":",dice_tries[i][0], dice_tries[i][1], end=' ')
      print(end=' ')
  ## write answer
  ##
  ##
  ##
  ##
  ##
  ##
  ##
  pass


print(colored("\n실제 값 : 0.138889", "red"))
print(colored(f"계산된 값 : {round(hits / num_iterations,6)}", "red"))
print(colored(f"오차율 : {abs(hits / num_iterations - 5/36) / (5/36) * 100} %", "red"))
print("="*100)
# Out:
# []
# ====================================================================================================
# * 두 주사위의 합이 8인 경우에는 cyan 색의 음영이 들어가 있음 *
# try  0 : 5 5  try  1 : 4 3  try  2 : 6 3  try  3 : 3 2  try  4 : 2 1
# try  5 : 3 3  try  6 : 6 5  try  7 : 3 4  try  8 : 3 1  try  9 : 2 3
# try  10 : 1 3  try  11 : 6 5  try  12 : 1 5  try  13 : 2 6  try  14 : 4 3
# try  15 : 3 6  try  16 : 2 4  try  17 : 4 4  try  18 : 1 4  try  19 : 6 1
# try  20 : 1 5  try  21 : 2 2  try  22 : 2 2  try  23 : 4 5  try  24 : 4 5
# try  25 : 2 5  try  26 : 5 3  try  27 : 6 4  try  28 : 4 2  try  29 : 2 1
# try  30 : 3 5  try  31 : 5 5  try  32 : 1 1  try  33 : 3 1  try  34 : 2 5
# try  35 : 1 2  try  36 : 3 3  try  37 : 4 1  try  38 : 6 3  try  39 : 1 2
# try  40 : 2 3  try  41 : 2 4  try  42 : 6 6  try  43 : 1 5  try  44 : 3 2
# try  45 : 3 3  try  46 : 2 6  try  47 : 2 6  try  48 : 2 1  try  49 : 4 4
# try  50 : 1 3  try  51 : 2 2  try  52 : 4 4  try  53 : 2 2  try  54 : 1 6
# try  55 : 5 1  try  56 : 5 5  try  57 : 3 5  try  58 : 5 4  try  59 : 1 6
# try  60 : 1 6  try  61 : 4 1  try  62 : 5 6  try  63 : 6 2  try  64 : 6 2
# try  65 : 6 6  try  66 : 1 2  try  67 : 1 1  try  68 : 2 1  try  69 : 3 1
# try  70 : 5 1  try  71 : 6 3  try  72 : 6 1  try  73 : 3 3  try  74 : 3 3
# try  75 : 5 6  try  76 : 4 3  try  77 : 5 6  try  78 : 6 1  try  79 : 4 1
# try  80 : 2 3  try  81 : 2 2  try  82 : 5 4  try  83 : 1 1  try  84 : 2 3
# try  85 : 2 6  try  86 : 5 4  try  87 : 3 2  try  88 : 4 5  try  89 : 1 5
# try  90 : 4 4  try  91 : 3 2  try  92 : 1 1  try  93 : 6 1  try  94 : 6 2
# try  95 : 5 5  try  96 : 2 2  try  97 : 5 2  try  98 : 6 4  try  99 : 1 5
#
# 실제 값 : 0.138889
# 계산된 값 : 0.14
# 오차율 : 0.800000000000005 %
# ====================================================================================================

# %% [markdown]
# # 실습 4. 주사위 게임

# %%
def roll_dice():
    line=[]
    x= random.randint(1,6)
    y= random.randint(1,6)
    return x, y
    pass

# %%
# Inputs
num_simulations = 10000
max_num_rolls = 1000
bet = 1


win_probability = []
end_balance = []

# %%
plt.figure(figsize=(12,6))
avg=[]
winning=[]
for i in range(num_simulations):
    money=1000
    xx=[]
    yy=[]
    w=0
    for j in range(max_num_rolls):

      dice_game=[]
      dice_game=roll_dice()
      if dice_game[0]==dice_game[1]:
        money+=4
        money-=bet
        w+=1
      else:
        money=money-1
      xx.append(j)
      yy.append(money)
    plt.plot(xx, yy)
    avg.append(np.mean(yy))
    winning.append(w)
   # print(money, i)
    continue

plt.title("Monte Carlo Dice Game [" + str(num_simulations) + " players simulations]")
plt.xlabel("Roll Number")
plt.ylabel("Balance [$]")
plt.xlim([0, max_num_rolls])

print(num_simulations,"명 플레이어의",max_num_rolls,"번 수행 횟수 시 평균 승률: ",np.mean(winning)/max_num_rolls) 
print(num_simulations,"명 플레이어의",max_num_rolls,"번 수행 횟수 시 평균 잔액: $",np.mean(avg))
# Out:
# 10000 명 플레이어의 1000 번 수행 횟수 시 평균 승률:  0.1667467
# 10000 명 플레이어의 1000 번 수행 횟수 시 평균 잔액: $ 833.5834976

# %%
overall_win_probability = np.mean(winning)/max_num_rolls
overall_end_balance = np.mean(avg)

print(f"10000명 플레이어의 {max_num_rolls}번 수행 횟수 시 평균 승률" + "  :  " + colored(f"{overall_win_probability:.2f}","red"))
print(f"10000명 플레이어의 {max_num_rolls}번 수행 횟수 시 평균 잔액 "  + f" : {colored('$','red')}" + colored(f"{overall_end_balance:.2f}","red"))
# Out:
# 10000명 플레이어의 1000번 수행 횟수 시 평균 승률  :  0.17
# 10000명 플레이어의 1000번 수행 횟수 시 평균 잔액  : $833.58

# %% [markdown]
# # 실습 5. 원주율 구하기

# %% [markdown]
# # 초기 세팅

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as patches

pi = 0



plt.rcParams['figure.figsize'] = (24, 12)
font1 = {'family': 'serif',
      'color':  'darkred',
      'weight': 'normal',
      'size': 16}
box1 = {'boxstyle': 'round',
        'ec': (1.0, 0.5, 0.5),
        'fc': (1.0, 0.8, 0.8)}

fig, ax = plt.subplots(1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.tick_params('both', length=0)    
ax.set_aspect('equal')




ax.text(-1.8,1.5, f"Estimated pi : {pi:.6f}\nReal pi : 3.141593\nError rate : {abs(pi-3.141593)/3.141593*100:.2f}%", fontdict=font1, bbox=box1)
ax.patch.set_facecolor('#069af3') ## axes 배경색
ax.patch.set_alpha(0.5) ## axes 투명도
ax.add_patch(
   patches.Rectangle(
      (-1, -1),                   # (x, y)
      2, 2,                     # width, height
      edgecolor = 'black',
      facecolor = 'lightgray',
      fill=False,
   ))
plt.xlim([-2,2])
plt.ylim([-2,2])


plt.show()

# %% [markdown]
# # pi 추측

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as patches

MAX_POINTS = 20000
x_coords = []
y_coords = []
in_markers = []


x_ran = []
y_ran = []
c_x = []
c_y = []

for _ in range(MAX_POINTS):
    x =random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    x_ran.append(x)
    y_ran.append(y)

    if np.sqrt(x ** 2 + y ** 2) <= 1:
        c_x.append(x)
        c_y.append(y)





plt.rcParams['figure.figsize'] = (24, 12)
font1 = {'family': 'serif',
      'color':  'darkred',
      'weight': 'normal',
      'size': 16}
box1 = {'boxstyle': 'round',
        'ec': (1.0, 0.5, 0.5),
        'fc': (1.0, 0.8, 0.8)}

fig, ax = plt.subplots(1)

ax.scatter(x_ran, y_ran)
ax.scatter(c_x, c_y, c='r')
red = len(c_x) / len(x_ran)
pi = red * 4

ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.tick_params('both', length=0)    
ax.set_aspect('equal')
ax.text(-1.8,1.4, f"Number of iteration : {MAX_POINTS}\nEstimated pi : {pi:.6f}\nReal pi : 3.141593\nError rate : {abs(pi-3.141593)/3.141593*100:.2f}%", fontdict=font1, bbox=box1)
ax.patch.set_facecolor('#069af3') ## axes 배경색
ax.patch.set_alpha(0.5) ## axes 투명도
ax.add_patch(
   patches.Rectangle(
      (-1, -1),                   # (x, y)
      2, 2,                     # width, height
      edgecolor = 'black',
      facecolor = 'lightgray',
      fill=False,
   ))
plt.xlim([-2,2])
plt.ylim([-2,2])
# Out:
# (-2.0, 2.0)

# %% [markdown]
# # 정확도를 0.1% 미만으로 만들어 보기

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as patches

MAX_POINTS = 150000
x_coords = []
y_coords = []
in_markers = []

c_x = []
c_y = []
x_ran = []
y_ran = []


for _ in range(MAX_POINTS):
    x =random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    x_ran.append(x)
    y_ran.append(y)

    if np.sqrt(x ** 2 + y ** 2) <= 1:
        c_x.append(x)
        c_y.append(y)





plt.rcParams['figure.figsize'] = (24, 12)
font1 = {'family': 'serif',
      'color':  'darkred',
      'weight': 'normal',
      'size': 16}
box1 = {'boxstyle': 'round',
        'ec': (1.0, 0.5, 0.5),
        'fc': (1.0, 0.8, 0.8)}

fig, ax = plt.subplots(1) 

ax.scatter(x_ran, y_ran)
ax.scatter(c_x, c_y, c='r')
red = len(c_x) / len(x_ran)
pi = red * 4

ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.tick_params('both', length=0)    
ax.set_aspect('equal')
ax.text(-1.8,1.4, f"Number of iteration : {MAX_POINTS}\nEstimated pi : {pi:.6f}\nReal pi : 3.141593\nError rate : {abs(pi-3.141593)/3.141593*100:.2f}%", fontdict=font1, bbox=box1)
ax.patch.set_facecolor('#069af3') ## axes 배경색
ax.patch.set_alpha(0.5) ## axes 투명도
ax.add_patch(
   patches.Rectangle(
      (-1, -1),                   # (x, y)
      2, 2,                     # width, height
      edgecolor = 'black',
      facecolor = 'lightgray',
      fill=False,
   ))
plt.xlim([-2,2])
plt.ylim([-2,2])
# Out:
# (-2.0, 2.0)

# %% [markdown]
# # 실습 6. 계약 손익 예측

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# 시뮬레이션 횟수
N_ROUNDS = 10000
results = []
for rnd in range(N_ROUNDS):
    win=random.randint(1,2)  #1이 문학상
    mon=np.random.triangular(1, 3, 9)

    if win==1:
      plus=np.random.triangular(0.25, 0.5, 0.75)
      mon=mon*(plus+1)

    sales = mon
    results.append(sales)

# %%
# 모든 시나리오에서 나온 신작 판매량의 평균 
average_sales = np.mean(results)

binned_results = pd.cut(results, bins=[0, 6, 20], labels=[
    "Probability : less than or equal to 600 million won",
    "Probability : greater than 600 million won"])

# 결과물 시각화
sns.barplot(x=binned_results.value_counts().index,
            y=binned_results.value_counts().values)
## write answer
##

# %%
C1 , C2 = binned_results.value_counts()
P1 = round(C1*100/N_ROUNDS, 2)
P2 = round(C2*100/N_ROUNDS, 2)

print("6억원 이하의 매출을 얻을 확률 :", colored(f"{P1}","red") )
print("6억원 초과의 매출을 얻을 확률 :", colored(f"{P2}","blue"))
# Out:
# 6억원 이하의 매출을 얻을 확률 : 64.15
# 6억원 초과의 매출을 얻을 확률 : 35.85

# %% [markdown]
# 실습 7

# %%
import numpy as np
import seaborn as sns
from termcolor import colored

# %%
np.random.seed(1)
subscription_data = {"Month": range(1, 60), 
                     "Growth": np.random.normal(0, 0.05, 60)}

N_ROUNDS = 10000
results = []
mem=[]
historical_data = subscription_data["Growth"]
mem.append(2000)

for rnd in range(N_ROUNDS):
    ## write answer
    sum=[]
    ran=[]
    for k in range(60):
      p=random.randint(1, 60)
      mem.append(mem[k-1]*(1+historical_data[k-1]))
    #  print(mem[k])

    for j in range(12):
      p=random.randint(1, 60)
      ran.append(mem[p])
      sum.append((mem[p]*50000))
     # print(sum[j])
    results.append(np.mean(sum))
  #  print(np.mean(ran))
    pass
#sns.displot(results, kind="kde")

plt.hist(results, bins=50, label='bins=50')

sorted(results);
print("99%의 신뢰구간 : ", sorted(results)[50]," ~ ",sorted(results)[10000-50])
# Out:
# 99%의 신뢰구간 :  79296397.18649484  ~  118459243.1525194

# %% [markdown]
# # 99%의 신뢰도
# - 10000개의 수행 결과를 낮은 수익부터 순서대로 정렬하고 100번째(100/10000)번째의 수익을 확인

# %%
print("하위 1%의 수익 : ", colored(f"{sorted(results)[100] / 1e8:.4f} 억","red"))

lower_revenue = sorted(results)[100]
print(f"매년 준비해야할 금액 : ",  colored(f"{(12*9.5*1e7 - lower_revenue)/1e8:.4f} 억","red"))
# Out:
# 하위 1%의 수익 :  0.8119 억
# 매년 준비해야할 금액 :  10.5881 억
